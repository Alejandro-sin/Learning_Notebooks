# %%
import requests as rq
from bs4 import BeautifulSoup

# %%
url = "http://www.pagina12.com.ar/"
p12 = rq.get(url)
text = p12.text

# %% [markdown]
# La diferencia entre p12.text y p12.content es que con content tengo disponible los contenidos multimedias. Este objeto es proveniente de requests.

# %%
# Obtengo el encabezado de la respuesta
p12.headers
# Out:
# {'Date': 'Mon, 18 Jan 2021 00:03:46 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dcb722cd3c189f0b7b9ab9729e7a822c01610928226; expires=Wed, 17-Feb-21 00:03:46 GMT; path=/; domain=.pagina12.com.ar; HttpOnly; SameSite=Lax', 'Vary': 'Accept-Encoding', 'X-DNS-Prefetch-Control': 'off', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains', 'X-Download-Options': 'noopen', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'X-ETag': 'W/"629ca-TTP/tlFlTJkm4CqF81JoRKTjscQ"', 'X-Backend': 'frontend', 'X-Backend-TTL': '180.000', 'X-Type': 'Dynamic URI', 'Age': '2', 'grace': '86400.000 none', 'ttl': '117.314', 'X-Instance': 'cache-front-prod-varnish-68cf7d4bd6-p6n6m', 'x-restarts': '0', 'X-Cache': 'HIT (11)', 'CF-Cache-Status': 'DYNAMIC', 'cf-request-id': '07b467183b0000e7882b30d000000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/
# ...

# %%
# Obtengo el encabezado de la solciutd
# Algunas páginas bloquean el User Agent de la solciitud ya que detecta la librería con la que trabaja, estos encabezados peuden modificarse.
# Que sirve para enmascarar.
p12.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %% [markdown]
# El parser separa pequeños pedazos que convertira.

# %%
soup = BeautifulSoup(text,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Página12 | La otra mirada
#   </title>
#   <meta content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg" name="google-site-verification"/>
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "Organization","name": "Página12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","https://www.facebook.com/Pagina12ok/"]}
#   </script>
#   <meta content="Notas focalizadas en el quehacer político de la Argentina." name="description" property="description"/>
#   <meta content="1541638399393436" name="fb:pages" property="fb:pages"/>
#   <meta content="es_AR" name="og:locale" property="og:locale"/>
# ...
